# %% [markdown]
# <a href="https://colab.research.google.com/github/moniaa59/dw_matrix_road_sign/blob/master/day5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install hyperopt
# Out:
# Requirement already satisfied: hyperopt in /usr/local/lib/python3.6/dist-packages (0.1.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.6/dist-packages (from hyperopt) (2.4)
# Requirement already satisfied: pymongo in /usr/local/lib/python3.6/dist-packages (from hyperopt) (3.10.1)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from hyperopt) (0.16.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from hyperopt) (1.18.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from hyperopt) (4.38.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from hyperopt) (1.4.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from hyperopt) (1.12.0)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx->hyperopt) (4.4.2)

# %%
import pandas as pd
import numpy as np
import os
import datetime

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout
from tensorflow.keras.utils import to_categorical

# %reload_ext tensorboard

import matplotlib.pyplot as plt
from skimage import color, exposure

from sklearn.metrics import accuracy_score
from hyperopt import hp, STATUS_OK, tpe, Trials, fmin

# %%
cd '/content/drive/My Drive/Colab Notebooks/matrix/matrix_three/dw_matrix_road_sign'
# Out:
# /content/drive/My Drive/Colab Notebooks/matrix/matrix_three/dw_matrix_road_sign

# %%
train = pd.read_pickle('data/train.p')
test = pd.read_pickle('data/test.p')

X_train, y_train = train['features'], train['labels']
X_test, y_test = test['features'], test['labels']

# %%
if y_train.ndim == 1: y_train = to_categorical(y_train)
if y_test.ndim == 1: y_test = to_categorical(y_test)

input_shape = X_train.shape[1:]
num_classes = y_train.shape[1]

# %%
def train_model(model, X_train, y_train, params_fit={}):
  model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])

  logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
  tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)

  model.fit(
      X_train, 
      y_train,
      batch_size=params_fit.get('batch_size', 128),
      epochs=params_fit.get('epochs',5),
      verbose=params_fit.get('verbose',1),
      validation_data=params_fit.get('validation_data', (X_train, y_train)),
      callbacks=[tensorboard_callback]

  )

  return model

def predict(model_trained, X_test, y_test, scoring=accuracy_score):

  y_test_norm = np.argmax(y_test, axis=1)

  y_pred_prob = model_trained.predict(X_test)
  y_pred = np.argmax(y_pred_prob, axis=1)

  return scoring(y_test_norm, y_pred)

# %%
def get_cnn_v5(input_shape, num_classes):
  return Sequential([
    Conv2D(filters=32, kernel_size=(3,3), activation='relu', input_shape=input_shape),
    Conv2D(filters=32, kernel_size=(3,3), activation='relu', padding='same'),
    MaxPool2D(),
    Dropout(0.3),

    Conv2D(filters=64, kernel_size=(3,3), activation='relu', padding='same'),
    Conv2D(filters=64, kernel_size=(3,3), activation='relu'),
    MaxPool2D(),
    Dropout(0.3),

    Conv2D(filters=64, kernel_size=(3,3), activation='relu', padding='same'),
    Conv2D(filters=64, kernel_size=(3,3), activation='relu'),
    MaxPool2D(),
    Dropout(0.3),

    Flatten(),

    Dense(1024, activation='relu'),   
    Dropout(0.3),

    Dense(1024, activation='relu'),   
    Dropout(0.3),

    Dense(num_classes, activation='softmax')          
  ])

# %%
model = get_cnn_v5(input_shape, num_classes)
model_trained = train_model(model, X_train, y_train)

predict(model_trained,X_test,y_test)
# Out:
# Epoch 1/5
# 272/272 [==============================] - 7s 25ms/step - loss: 2.5616 - accuracy: 0.2782 - val_loss: 1.1715 - val_accuracy: 0.6358
# Epoch 2/5
# 272/272 [==============================] - 6s 23ms/step - loss: 1.0363 - accuracy: 0.6734 - val_loss: 0.3994 - val_accuracy: 0.8811
# Epoch 3/5
# 272/272 [==============================] - 6s 22ms/step - loss: 0.5727 - accuracy: 0.8171 - val_loss: 0.1882 - val_accuracy: 0.9454
# Epoch 4/5
# 272/272 [==============================] - 6s 22ms/step - loss: 0.4169 - accuracy: 0.8670 - val_loss: 0.1744 - val_accuracy: 0.9484
# Epoch 5/5
# 272/272 [==============================] - 6s 22ms/step - loss: 0.3615 - accuracy: 0.8886 - val_loss: 0.0785 - val_accuracy: 0.9781
# 0.9482993197278912

# %%
model_trained.evaluate(X_test,y_test)
# Out:
# 138/138 [==============================] - 0s 3ms/step - loss: 0.1834 - accuracy: 0.9483
# [0.18338508903980255, 0.9482993483543396]

# %%
def get_model(params):
  return Sequential([
    Conv2D(filters=32, kernel_size=(3,3), activation='relu', input_shape=input_shape),
    Conv2D(filters=32, kernel_size=(3,3), activation='relu', padding='same'),
    MaxPool2D(),
    Dropout(params['dropout_cnn_block_one']),

    Conv2D(filters=64, kernel_size=(3,3), activation='relu', padding='same'),
    Conv2D(filters=64, kernel_size=(3,3), activation='relu'),
    MaxPool2D(),
    Dropout(params['dropout_cnn_block_two']),

    Conv2D(filters=128, kernel_size=(3,3), activation='relu', padding='same'),
    Conv2D(filters=128, kernel_size=(3,3), activation='relu'),
    MaxPool2D(),
    Dropout(params['dropout_cnn_block_three']),

    Flatten(),

    Dense(1024, activation='relu'),   
    Dropout(params['dropout_cnn_block_one']),

    Dense(1024, activation='relu'),   
    Dropout(params['dropout_cnn_block_two']),

    Dense(num_classes, activation='softmax')          
  ])

# %%
def func_obj(params):
  model = get_model(params)
  model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])

  model.fit(
      X_train, 
      y_train,
      batch_size=int(params.get('batch_size', 128)),
      epochs=5,
      verbose=0

  )

  accuracy = model.evaluate(X_test, y_test)[0]
  print(params, 'accuracy={}'.format(accuracy))

  return {'loss': -accuracy, 'status': STATUS_OK, 'model': model}

# %%
space = {
    'batch_size': hp.quniform('batch_size', 100, 200, 10),
    'dropout_cnn_block_one': hp.uniform('dropout_cnn_block_one', 0.3, 0.5),
    'dropout_cnn_block_two': hp.uniform('dropout_cnn_block_two', 0.3, 0.5),
    'dropout_cnn_block_three': hp.uniform('dropout_cnn_block_three', 0.3, 0.5),


    'dropout_cnn_block_one': hp.uniform('dropout_cnn_block_one', 0.3, 0.7),
    'dropout_cnn_block_two': hp.uniform('dropout_cnn_block_two', 0.3, 0.7),

}

best = fmin(
    func_obj,
    space,
    tpe.suggest,
    30,
    Trials()
)
# Out:
#   1/138 [..............................]
#  - ETA: 0s - loss: 5.0439 - accuracy: 0.1875
#
#  13/138 [=>............................]
#  - ETA: 0s - loss: 0.6505 - accuracy: 0.8534
#
#  24/138 [====>.........................]
#  - ETA: 0s - loss: 0.5219 - accuracy: 0.8698
#
#  36/138 [======>.......................]
#  - ETA: 0s - loss: 0.4077 - accuracy: 0.8828
#
#  47/138 [=========>....................]
#  - ETA: 0s - loss: 0.4670 - accuracy: 0.8491
#
#  59/138 [===========>..................]
#  - ETA: 0s - loss: 0.4058 - accuracy: 0.8686
#
#  69/138 [==============>...............]
#  - ETA: 0s - loss: 0.3731 - accuracy: 0.8827
#
#  80/138 [================>.............]
#  - ETA: 0s - loss: 0.3228 - accuracy: 0.8988
#
#  91/138 [==================>...........]
#  - ETA: 0s - loss: 0.2966 - accuracy: 0.9069
#
# 102/138 [=====================>........]
#  - ETA: 0s - loss: 0.3058 - accuracy: 0.9047
#
# 112/138 [=======================>......]
#  - ETA: 0s - loss: 0.3064 - accuracy: 0.9046
#
# 122/138 [=========================>....]
#  - ETA: 0s - loss: 0.2866 - accuracy: 0.9103
#
# 130/138 [===========================>..]
#  - ETA: 0s - loss: 0.2760 - accuracy: 0.9137
#
# 138/138 [==============================]
#  - 1s 5ms/step - loss: 0.2718 - accuracy: 0.9159
#
# {'batch_size': 190.0, 'dropout_cnn_block_one': 0.3041443639640317, 'dropout_cnn_block_three': 0.35570547162720084, 'dropout_cnn_block_two': 0.4829201944185367}
# accuracy=0.27181726694107056
#   1/138 [..............................]
#  - ETA: 0s - loss: 2.8787 - accuracy: 0.0000e+00
#
#  11/138 [=>............................]
#  - ETA: 0s - loss: 2.4181 - accuracy: 0.1562
#
#  22/138 [===>..........................]
#  - ETA: 0s - loss: 2.7171 - accuracy: 0.0938
#
#  34/138 [======>.......................]
#  - ETA: 0s - loss: 2.6841 - accuracy: 0.0607
#
#  44/138 [========>.....................]
#  - ETA: 0s - loss: 2.6784 - accuracy: 0.0696
#
#  56/138 [===========>..................]
#  - ETA: 0s - loss: 2.5157 - accuracy: 0.1635
#
#  66/138 [=============>................]
#  - ETA: 0s - loss: 2.3698 - accuracy: 0.2547
#
#  77/138 [===============>..............]
#  - ETA: 0s - loss: 2.1968 - accuracy: 0.3028
#
#  88/138 [==================>...........]
#  - ETA: 0s - loss: 2.1699 - accuracy: 0.2901
#
#  98/138 [====================>.........]
#  - ETA: 0s - loss: 2.0914 - accuracy: 0.3166
#
# 109/138 [======================>.......]
#  - ETA: 0s - loss: 2.1583 - accuracy: 0.2847
#
# 119/138 [========================>.....]
#  - ETA: 0s - loss: 2.0105 - accuracy: 0.3348
#
# 129/138 [===========================>..]
#  - ETA: 0s - loss: 1.9981 - accuracy: 0.3394
#
# 138/138 [==============================]
#  - 1s 5ms/step - loss: 2.0171 - accuracy: 0.3444
#
# {'batch_size': 200.0, 'dropout_cnn_block_one': 0.6387915869368499, 'dropout_cnn_block_three': 0.49541968838733047, 'dropout_cnn_block_two': 0.5345102023957071}
# accuracy=2.017085552215576
#   1/138 [..............................]
#  - ETA: 0s - loss: 0.0775 - accuracy: 0.9688
#
#  14/138 [==>...........................]
#  - ETA: 0s - loss: 0.2326 - accuracy: 0.9107
#
#  26/138 [====>.........................]
#  - ETA: 0s - loss: 0.5484 - accuracy: 0.8774
#
#  37/138 [=======>......................]
#  - ETA: 0s - loss: 0.3892 - accuracy: 0.9139
#
#  47/138 [=========>....................]
#  - ETA: 0s - loss: 0.3977 - accuracy: 0.9062
#
#  57/138 [===========>..................]
#  - ETA: 0s - loss: 0.3561 - accuracy: 0.9145
#
#  67/138 [=============>................]
#  - ETA: 0s - loss: 0
#
# {'batch_size': 150.0, 'dropout_cnn_block_one': 0.439485412936208, 'dropout_cnn_block_three': 0.448350995320809, 'dropout_cnn_block_two': 0.5367507104562816}
# accuracy=0.5072205066680908
#   1/138 [..............................]
#  - ETA: 0s - loss: 3.7357 - accuracy: 0.0625
#
#  11/138 [=>............................]
#  - ETA: 0s - loss: 1.3973 - accuracy: 0.6165
#
#  23/138 [====>.........................]
#  - ETA: 0s - loss: 2.0643 - accuracy: 0.4674
#
#  33/138 [======>.......................]
#  - ETA: 0s - loss: 1.7432 - accuracy: 0.4792
#
#  42/138 [========>.....................]
#  - ETA: 0s - loss: 1.7513 - accuracy: 0.5022
#
#  52/138 [==========>...................]
#  - ETA: 0s - loss: 1.6997 - accuracy: 0.5066
#
#  58/138 [===========>..................]
#  - ETA: 0s - loss: 1.5923 - accuracy: 0.5506
#
#  66/138 [=============>................]
#  - ETA: 0s - loss: 1.4958 - accuracy: 0.5748
#
#  76/138 [===============>..............]
#  - ETA: 0s - loss: 1.3777 - accuracy: 0.6081
#
#  87/138 [=================>............]
#  - ETA: 0s - loss: 1.3695 - accuracy: 0.6009
#
#  97/138 [====================>.........]
#  - ETA: 0s - loss: 1.2956 - accuracy: 0.6134
#
# 106/138 [======================>.......]
#  - ETA: 0s - loss: 1.3570 - accuracy: 0.5761
#
# 116/138 [========================>.....]
#  - ETA: 0s - loss: 1.2820 - accuracy: 0.5999
#
# 124/138 [=========================>....]
#  - ETA: 0s - loss: 1.2482 - accuracy: 0.6142
#
# 134/138 [============================>.]
#  - ETA: 0s - loss: 1.2357 - accuracy: 0.6124
#
# 138/138 [==============================]
#  - 1s 5ms/step - loss: 1.2155 - accuracy: 0.6220
#
# {'batch_size': 150.0, 'dropout_cnn_block_one': 0.6661205880179177, 'dropout_cnn_block_three': 0.3309659855936632, 'dropout_cnn_block_two': 0.4256324172264519}
# accuracy=1.2154879570007324
#   1/138 [..............................]
#  - ETA: 0s - loss: 1.6884 - accuracy: 0.1875
#
#  13/138 [=>............................]
#  - ETA: 0s - loss: 2.2551 - accuracy: 0.2837
#
#  23/138 [====>.........................]
#  - ETA: 0s - loss: 2.9936 - accuracy: 0.1834
#
#  33/138 [======>.......................]
#  - ETA: 0s - loss: 2.7483 - accuracy: 0.1591
#
#  44/138 [========>.....................]
#  - ETA: 0s - loss: 2.6886 - accuracy: 0.1314
#
#  54/138 [==========>...................]
#  - ETA: 0s - loss: 2.6873 - accuracy: 0.1574
#
#  63/138 [============>.................]
#  - ETA: 0s - loss: 2.4056 - accuracy: 0.2763
#
#  69/138 [==============>...............]
#  - ETA: 0s - loss: 2.3375 - accuracy: 0.2736
#
#  79/138 [================>.............]
#  - ETA: 0s - loss: 2.0860 - accuracy: 0.3564
#
#  90/138 [==================>...........]
#  - ETA: 0s - loss: 1.9735 - accuracy: 0.3767
#
#  99/138 [====================>.........]
#  - ETA: 0s - loss: 1.9010 - accuracy: 0.3804
#
# 110/138 [======================>.......]
#  - ETA: 0s - loss: 1.9237 - accuracy: 0.3710
#
# 121/138 [=========================>....]
#  - ETA: 0s - loss: 1.8154 - accuracy: 0.4068
#
# 132/138 [===========================>..]
#  - ETA: 0s - loss: 1.8070 - accuracy: 0.4036
#
# 138/138 [==============================]
#  - 1s 5ms/step - loss: 1.8151 - accuracy: 0.4020
#
# {'batch_size': 200.0, 'dropout_cnn_block_one': 0.6263462720356957, 'dropout_cnn_block_three': 0.30301612805117795, 'dropout_cnn_block_two': 0.5882474958296462}
# accuracy=1.815075397491455
#   1/138 [..............................]
#  - ETA: 0s - loss: 2.5990 - accuracy: 0.0625
#
#  13/138 [=>............................]
#  - ETA: 0s - loss: 1.8418 - accuracy: 0.4423
#
#  24/138 [====>.........................]
#  - ETA: 0s - loss: 2.3506 - accuracy: 0.2773
#
#  36/138 [======>.......................]
#  - ETA: 0s - loss: 2.2234 - accuracy: 0.1944
#
#  48/138 [=========>....................]
#  - ETA: 0s - loss: 2.3740 - accuracy: 0.1745
#
#  59/138 [===========>..................]
#  - ETA: 0s - loss: 2.2746 - accuracy: 0.2521
#
#  70/138 [==============>...............]
#  - ETA: 0s - loss: 2.1320 - accuracy: 0.3161
#
#  82/138 [================>.............]
#  - ETA: 0s - loss: 1.9825 - accuracy: 0.3396
#
#  93/138 [===================>..........]
#  - ETA: 0s - loss: 1.8141 - accuracy: 0.3925
#
# 104/138 [=====================>........]
#  - ETA: 0s - loss: 1.8412 - accuracy: 0.3585
#
# 114/138 [=======================>......]
#  - ETA: 0s - loss: 1.7921 - accuracy: 0.3649
#
# 124/138 [=========================>....]
#  - ETA: 0s - loss: 1.6931 - accuracy: 0.4007
#
# 132/138 [===========================>..]
#  - ETA: 0s - loss: 1.6667 - accuracy: 0.4141
#
# 138/138 [==============================]
#  - 1s 5ms/step - loss: 1.6583 - accuracy: 0.4315
#
# {'batch_size': 100.0, 'dropout_cnn_block_one': 0.6250178532024149, 'dropout_cnn_block_three': 0.3041273297727614, 'dropout_cnn_block_two': 0.6998745596142527}
# accuracy=1.658297061920166
#   1/138 [..............................]
#  - ETA: 0s - loss: 3.4964 - accuracy: 0.0625
#
#  13/138 [=>............................]
#  - ETA: 0s - loss: 2.0854 - accuracy: 0.4591
#
#  24/138 [====>.........................]
#  - ETA: 0s - loss: 2.3376 - accuracy: 0.2969
#
#  35/138 [======>.......................]
#  - ETA: 0s - loss: 2.2005 - accuracy: 0.2188
#
#  45/138 [========>.....................]
#  - ETA: 0s - loss: 2.2698 - accuracy: 0.1819
#
#  56/138 [===========>..................]
#  - ETA: 0s - loss: 2.1536 - accuracy: 0.2416
#
#  65/138 [=============>................]
#  - ETA: 0s - loss: 1.9880 - accuracy: 0.3226
#
#  76/138 [===============>..............]
#  - ETA: 0s - loss: 1.8105 - accuracy: 0.3717
#
#  88/138 [==================>...........]
#  - ETA: 0s - loss: 1.7262 - accuracy: 0.3832
#
# 100/138 [====================>.........]
#  - ETA: 0s - loss: 1.6676 - accuracy: 0.3928
#
# 110/138 [======================>.......]
#  - ETA: 0s - loss: 1.7037 - accuracy: 0.3838
#
# 119/138 [========================>.....]
#  - ETA: 0s - loss: 1.5775 - accuracy: 0.4296
#
# 131/138 [===========================>..]
#  - ETA: 0s - loss: 1.5818 - accuracy: 0.4361
#
# 138/138 [==============================]
#  - 1s 5ms/step - loss: 1.5816 - accuracy: 0.4556
#
# {'batch_size': 200.0, 'dropout_cnn_block_one': 0.6232144689838551, 'dropout_cnn_block_three': 0.3015118939876194, 'dropout_cnn_block_two': 0.584257852608411}
# accuracy=1.5816291570663452
#   1/138 [..............................]
#  - ETA: 0s - loss: 2.9224 - accuracy: 0.0000e+00
#
#  11/138 [=>............................]
#  - ETA: 0s - loss: 2.6437 - accuracy: 0.0483
#
#  22/138 [===>..........................]
#  - ETA: 0s - loss: 2.7435 - accuracy: 0.0994
#
#  32/138 [=====>........................]
#  - ETA: 0s - loss: 2.7491 - accuracy: 0.0684
#
#  43/138 [========>.....................]
#  - ETA: 0s - loss: 2.6988 - accuracy: 0.0741
#
#  53/138 [==========>...................]
#  - ETA: 0s - loss: 2.7330 - accuracy: 0.0985
#
#  64/138 [============>.................]
#  - ETA: 0s - loss: 2.5059 - accuracy: 0.2417
#
#  74/138 [===============>..............]
#  - ETA: 0s - loss: 2.3072 - accuracy: 0.2834
#
#  83/138 [=================>............]
#  - ETA: 0s - loss: 2.2464 - accuracy: 0.2643
#
#  95/138 [===================>..........]
#  - ETA: 0s - loss: 2.0737 - accuracy: 0.3105
#
# 106/138 [======================>.......]
#  - ETA: 0s - loss: 2.1567 - accuracy: 0.2783
#
# 116/138 [========================>.....]
#  - ETA: 0s - loss: 2.0460 - accuracy: 0.3087
#
# 124/138 [=========================>....]
#  - ETA: 0s - loss: 1.9950 - accuracy: 0.3261
#
# 135/138 [============================>.]
#  - ETA: 0s - loss: 1.9852 - accuracy: 0.3243
#
# 138/138 [==============================]
#  - 1s 5ms/step - loss: 1.9819 - accuracy: 0.3363
#
# {'batch_size': 200.0, 'dropout_cnn_block_one': 0.5994310443484335, 'dropout_cnn_block_three': 0.43959741662568397, 'dropout_cnn_block_two': 0.6916328972672925}
# accuracy=1.9818933010101318
#   1/138 [..............................]
#  - ETA: 0s - loss: 1.5018 - accuracy: 0.7188
#
#  12/138 [=>............................]
#  - ETA: 0s - loss: 1.7854 - accuracy: 0.4661
#
#  23/138 [====>.........................]
#  - ETA: 0s - loss: 2.0703 - accuracy: 0.3967
#
#  35/138 [======>.......................]
#  - ETA: 0s - loss: 1.9592 - accuracy: 0.2830
#
#  47/138 [=========>....................]
#  - ETA: 0s - loss: 1.9756 - accuracy: 0.3258
#
#  59/138 [===========>..................]
#  - ETA: 0s - loss: 1.7818 - accuracy: 0.4211
#
#  70/138 [==============>...............]
#  - ETA: 0s - loss: 1.6798 - accuracy: 0.4799
#
#  81/138 [================>.............]
#  - ETA: 0s - loss: 1.5726 - accuracy: 0.4869
#
#  93/138 [===================>..........]
#  - ETA: 0s - loss: 1.4013 - accuracy: 0.5504
#
# 101/138 [====================>.........]
#  - ETA: 0s - loss: 1.3929 - accuracy: 0.5427
#
# 111/138 [=======================>......]
#  - ETA: 0s - loss: 1.4505 - accuracy: 0.5076
#
# 121/138 [=========================>....]
#  - ETA: 0s - loss: 1.3395 - accuracy: 0.5465
#
# 132/138 [===========================>..]
#  - ETA: 0s - loss: 1.3263 - accuracy: 0.5384
#
# 138/138 [==============================]
#  - 1s 5ms/step - loss: 1.3165 - accuracy: 0.5431
#
# {'batch_size': 110.0, 'dropout_cnn_block_one': 0.5180116183528558, 'dropout_cnn_block_three': 0.43542632123380454, 'dropout_cnn_block_two': 0.693722818916729}
# accuracy=1.3164947032928467
#   1/138 [..............................]
#  - ETA: 0s - loss: 2.8076 - accuracy: 0.0625
#
#  12/138 [=>............................]
#  - ETA: 0s - loss: 2.1331 - accuracy: 0.3932
#
#  22/138 [===>..........................]
#  - ETA: 0s - loss: 2.2891 - accuracy: 0.2983
#
#  33/138 [======>.......................]
#  - ETA: 0s - loss: 2.1325 - accuracy: 0.3419
#
#  43/138 [========>.....................]
#  - ETA: 0s - loss: 2.1324 - accuracy: 0.3060
#
#  55/138 [==========>...................]
#  - ETA: 0s - loss: 2.1477 - accuracy: 0.3068
#
#  64/138 [============>.................]
#  - ETA: 0s - loss: 1.9132 - accuracy: 0.3872
#
#  75/138 [===============>..............]
#  - ETA: 0s - loss: 1.7415 - accuracy: 0.4183
#
#  86/138 [=================>............]
#  - ETA: 0s - loss: 1.6356 - accuracy: 0.4426
#
#  97/138 [====================>.........]
#  - ETA: 0s - loss: 1.5120 - accuracy: 0.4755
#
# 108/138 [======================>.......]
#  - ETA: 0s - loss: 1.5335 - accuracy: 0.4664
#
# 119/138 [========================>.....]
#  - ETA: 0s - loss: 1.4465 - accuracy: 0.4979
#
# 129/138 [===========================>..]
#  - ETA: 0s - loss: 1.4480 - accuracy: 0.5073
#
# 138/138 [==============================]
#  - 1s 5ms/step - loss: 1.4628 - accuracy: 0.5163
#
# {'batch_size': 170.0, 'dropout_cnn_block_one': 0.5777481170119333, 'dropout_cnn_block_three': 0.4975789949089416, 'dropout_cnn_block_two': 0.44834482217022176}
# accuracy=1.4627761840820312
#   1/138 [..............................]
#  - ETA: 0s - loss: 3.2977 - accuracy: 0.0000e+00
#
#  11/138 [=>............................]
#  - ETA: 0s - loss: 2.5352 - accuracy: 0.3011
#
#  23/138 [====>.........................]
#  - ETA: 0s - loss: 2.7536 - accuracy: 0.2527
#
#  35/138 [======>.......................]
#  - ETA: 0s - loss: 2.6106 - accuracy: 0.1759
#
#  48/138 [=========>....................]
#  - ETA: 0s - loss: 2.6581 - accuracy: 0.1458
#
#  58/138 [===========>..................]
#  - ETA: 0s - loss: 2.5182 - accuracy: 0.1859
#
#  68/138 [=============>................]
#  - ETA: 0s - loss: 2.4117 - accuracy: 0.2302
#
#  77/138 [===============>..............]
#  - ETA: 0s - loss: 2.2340 - accuracy: 0.2890
#
#  87/138 [=================>............]
#  - ETA: 0s - loss: 2.2428 - accuracy: 0.2662
#
#  97/138 [====================>.........]
#  - ETA: 0s - loss: 2.1764 - accuracy: 0.2967
#
# 106/138 [======================>.......]
#  - ETA: 0s - loss: 2.2364 - accuracy: 0.2718
#
# 116/138 [========================>.....]
#  - ETA: 0s - loss: 2.1357 - accuracy: 0.3025
#
# 126/138 [==========================>...]
#  - ETA: 0s - loss: 2.0650 - accuracy: 0.3289
#
# 138/138 [==============================]
#  - ETA: 0s - loss: 2.0733 - accuracy: 0.3302
#
# 138/138 [==============================]
#  - 1s 5ms/step - loss: 2.0733 - accuracy: 0.3302
#
# {'batch_size': 190.0, 'dropout_cnn_block_one': 0.6079821489312719, 'dropout_cnn_block_three': 0.46183032540326446, 'dropout_cnn_block_two': 0.6868789650332936}
# accuracy=2.0732779502868652
#   1/138 [..............................]
#  - ETA: 0s - loss: 2.5664 - accuracy: 0.0000e+00
#
#  12/138 [=>............................]
#  - ETA: 0s - loss: 2.2720 - accuracy: 0.1328
#
#  23/138 [====>.........................]
#  - ETA: 0s - loss: 2.5614 - accuracy: 0.2052
#
#  35/138 [======>.......................]
#  - ETA: 0s - loss: 2.3495 - accuracy: 0.1634
#
#  47/138 [=========>....................]
#  - ETA: 0s - loss: 2.4125 - accuracy: 0.1383
#
#  58/138 [===========>..................]
#  - ETA: 0s - loss: 2.1811 - accuracy: 0.2117
#
#  71/138 [==============>...............]
#  - ETA: 0s - loss: 1.9358 - accuracy: 0.3393
#
#  82/138 [================>.............]
#  - ETA: 0s - loss: 1.8350 - accuracy: 0.3704
#
#  91/138 [==================>...........]
#  - ETA: 0s - loss: 1.7407 - accuracy: 0.4038
#
# 102/138 [=====================>........]
#  - ETA: 0s - loss: 1.7394 - accuracy: 0.3873
#
# 113/138 [=======================>......]
#  - ETA: 0s - loss: 1.7440 - accuracy: 0.3789
#
# 123/138 [=========================>....]
#  - ETA: 0s - loss: 1.6312 - accuracy: 0.4146
#
# 134/138 [============================>.]
#  - ETA: 0s - loss: 1.6159 - accuracy: 0.4137
#
# 138/138 [==============================]
#  - 1s 5ms/step - loss: 1.6204 - accuracy: 0.4299
#
# {'batch_size': 190.0, 'dropout_cnn_block_one': 0.5249402657138799, 'dropout_cnn_block_three': 0.4666824315660848, 'dropout_cnn_block_two': 0.6765766117052537}
# accuracy=1.6203968524932861
#   1/138 [..............................]
#  - ETA: 0s - loss: 1.1402 - accuracy: 0.5312
#
#  13/138 [=>............................]
#  - ETA: 0s - loss: 0.6130 - accuracy: 0.8221
#
#  24/138 [====>.........................]
#  - ETA: 0s - loss: 0.9288 - accuracy: 0.7747
#
#  36/138 [======>.......................]
#  - ETA: 0s - loss: 0.6704 - accuracy: 0.8351
#
#  46/138 [=========>....................]
#  - ETA: 0s - loss: 0.7003 - accuracy: 0.8193
#
#  53/138 [==========>...................]
#  - ETA: 0s - loss: 0.6800 - accuracy: 0.8143
#
#  63/138 [============>.................]
#  - ETA: 0s - loss: 0.6037 - accuracy: 0.8358
#
#  74/138 [===============>..............]
#  - ETA: 0s - loss: 0.5864 - accuracy: 0.8260
#
#  86/138 [=================>............]
#  - ETA: 0s - loss: 0.5288 - accuracy: 0.8445
#
#  98/138 [====================>.........]
#  - ETA: 0s - loss: 0.4857 - accuracy: 0.8597
#
# 109/138 [======================>.......]
#  - ETA: 0s - loss: 0.5213 - accuracy: 0.8460
#
# 121/138 [=========================>....]
#  - ETA: 0s - loss: 0.4741 - accuracy: 0.8603
#
# 131/138 [===========================>..]
#  - ETA: 0s - loss: 0.4689 - accuracy: 0.8569
#
# 138/138 [==============================]
#  - 1s 5ms/step - loss: 0.4560 - accuracy: 0.8612
#
# {'batch_size': 170.0, 'dropout_cnn_block_one': 0.4816657692071584, 'dropout_cnn_block_three': 0.47101892010093555, 'dropout_cnn_block_two': 0.5047037382986945}
# accuracy=0.4560171067714691
#   1/138 [..............................]
#  - ETA: 0s - loss: 2.9612 - accuracy: 0.0625
#
#  11/138 [=>............................]
#  - ETA: 0s - loss: 1.2469 - accuracy: 0.6108
#
#  23/138 [====>.........................]
#  - ETA: 0s - loss: 1.5066 - accuracy: 0.5516
#
#  35/138 [======>.......................]
#  - ETA: 0s - loss: 1.1140 - accuracy: 0.6705
#
#  46/138 [=========>....................]
#  - ETA: 0s - loss: 1.1661 - accuracy: 0.6420
#
#  57/138 [===========>..................]
#  - ETA: 0s - loss: 1.0503 - accuracy: 0.6798
#
#  68/138 [=============>................]
#  - ETA: 0s - loss: 1.0392 - accuracy: 0.7215
#
#  78/138 [===============>..............]
#  - ETA: 0s - loss: 0.9587 - accuracy: 0.7188
#
#  88/138 [==================>...........]
#  - ETA: 0s - loss: 0.9719 - accuracy: 0.7099
#
#  99/138 [====================>.........]
#  - ETA: 0s - loss: 0.9313 - accuracy: 0.6995
#
# 110/138 [======================>.......]
#  - ETA: 0s - loss: 1.0405 - accuracy: 0.6435
#
# 118/138 [========================>.....]
#  - ETA: 0s - loss: 0.9700 - accuracy: 0.6676
#
# 127/138 [==========================>...]
#  - ETA: 0s - loss: 0.9169 - accuracy: 0.6863
#
# 136/138 [============================>.]
#  - ETA: 0s - loss: 0.8877 - accuracy: 0.6946
#
# 138/138 [==============================]
#  - 1s 5ms/step - loss: 0.8760 - accuracy: 0.6986
#
# {'batch_size': 180.0, 'dropout_cnn_block_one': 0.5919188123549456, 'dropout_cnn_block_three': 0.49753416369706865, 'dropout_cnn_block_two': 0.46873350328481556}
# accuracy=0.8760392069816589
# 100%|██████████| 30/30 [09:59<00:00, 20.00s/it, best loss: -2.0732779502868652]
